# %% [markdown]
# <a href="https://colab.research.google.com/github/arez1997/PYMCDM/blob/master/simulation_senario6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=[[[2,0.00532],[3,0.00818],[3,0.0133],[2,0.00741],[1,0.000619],[3,0.00436],[3,0.0105],[3,0.0150],[2,0.00268],[3,0.0141],[2,0.00394],[1,0.00236],[2,0.00215],[3,0.0110]],
                 [[1,0.000726],[1,0.000619],[3,0.0110],[3,0.0124],[2,0.00431],[3,0.00567],[2,0.00466],[1,0.00105],[1,0.000101],[2,0.00683],[2,0.00355],[2,0.00769],[3,0.00436],[1,0.000834]],
                 [[2,0.00499],[2,0.00431],[3,0.0124],[2,0.00683],[3,0.00818],[2,0.00268],[2,0.00394],[3,0.0105],[1,0.000408],[1,0.00105],[2,0.00314],[3,0.0133],[3,0.00665],[2,0.00355]],
                 [[3,0.00818],[0,0],[2,0.00466],[0,0],[0,0],[1,0.000408],[0,0],[0,0],[1,0.000943],[0,0],[0,0],[3,0.0110],[0,0],[3,0.00436]]]
from datetime import datetime
start_time = datetime.now()
import random 
import numpy as np 
#senario1

#x[i+1:type of tool][i+1:subsystem][i=0: 'k' and i=1:'lambda' ]
#z(i:subsystem)(i:z1 or z2)(i: nember of z1 or z2)

n=[]
s1=[]
s2=[]
s3=[]
s4=[]
s5=[]
s6=[]
s7=[]
s8=[]
s9=[]
s10=[]
s11=[]
s12=[]
s13=[]
s14=[]
#re: teetad tekrar
re=1000000
for i in range(re):
  m=[]
  
  #sub1
  s=random.expovariate(-0.01*np.log(0.99))
  z111=random.gammavariate(x[2][0][0],1/x[2][0][1])
  z121=random.gammavariate(x[2][0][0],1/x[2][0][1])
  z122=random.gammavariate(x[2][0][0],1/x[2][0][1])
  if s>=z111:
    if s>= z111+z121:
      m.append(z111+z121+z122)
    else:
      m.append(z111+z121)
  else:
    m.append(z111)
  s1.append(m[-1])  

  #sub2
  s=random.expovariate(-0.01*np.log(0.99))
  z211=random.gammavariate(x[0][1][0],1/x[0][1][1])
  z221=random.gammavariate(x[0][1][0],1/x[0][1][1])
  if s>=z211:
    m.append(z211+z221)
  else:
    m.append(z211)
  s2.append(m[-1])  

  #sub3
  s=random.expovariate(-0.01*np.log(0.99))
  z311=random.gammavariate(x[3][2][0],1/x[3][2][1])
  z321=random.gammavariate(x[3][2][0],1/x[3][2][1])
  z322=random.gammavariate(x[3][2][0],1/x[3][2][1])
  if s>=z311:
    if s>= z311+z321:
      m.append(z311+z321+z322)
    else:
      m.append(z311+z321)
  else:
    m.append(z311)
  s3.append(m[-1])  
  
  #sub4
  s=random.expovariate(-0.01*np.log(0.99))
  z411=random.gammavariate(x[2][3][0],1/x[2][3][1])
  z421=random.gammavariate(x[2][3][0],1/x[2][3][1])
  z422=random.gammavariate(x[2][3][0],1/x[2][3][1])
  if s>=z411:
    if s>= z411+z421:
      m.append(z411+z421+z422)
    else:
      m.append(z411+z421)
  else:
    m.append(z411)
  s4.append(m[-1])

  #sub5
  s=random.expovariate(-0.01*np.log(0.99))
  z511=random.gammavariate(x[1][4][0],1/x[1][4][1])
  z521=random.gammavariate(x[1][4][0],1/x[1][4][1])
  z522=random.gammavariate(x[1][4][0],1/x[1][4][1])
  if s>=z511:
    if s>= z511+z521:
      m.append(z511+z521+z522)
    else:
      m.append(z511+z521)
  else:
    m.append(z511)
  s5.append(m[-1]) 

  #sub6
  s=random.expovariate(-0.01*np.log(0.99))
  z611=random.gammavariate(x[1][5][0],1/x[1][5][1])
  z621=random.gammavariate(x[1][5][0],1/x[1][5][1])
  if s>=z611:
    m.append(z611+z621)
  else:
    m.append(z611)
  s6.append(m[-1])

  #sub7
  s=random.expovariate(-0.01*np.log(0.99))
  z711=random.gammavariate(x[0][6][0],1/x[0][6][1])
  z721=random.gammavariate(x[0][6][0],1/x[0][6][1])
  if s>=z711:
    m.append(z711+z721)
  else:
    m.append(z711)
  s7.append(m[-1])    

  #sub8
  s=random.expovariate(-0.01*np.log(0.99))
  z811=random.gammavariate(x[0][7][0],1/x[0][7][1])
  z821=random.gammavariate(x[0][7][0],1/x[0][7][1])
  z822=random.gammavariate(x[0][7][0],1/x[0][7][1])
  if s>=z811:
    if s>= z811+z821:
      m.append(z811+z821+z822)
    else:
      m.append(z811+z821)
  else:
    m.append(z811)
  s8.append(m[-1])  

  #sub9
  s=random.expovariate(-0.01*np.log(0.99))
  z911=random.gammavariate(x[0][8][0],1/x[0][8][1])
  z921=random.gammavariate(x[0][8][0],1/x[0][8][1])
  if s>=z911:
    m.append(z911+z921)
  else:
    m.append(z911)
  s9.append(m[-1])

  #sub10
  s=random.expovariate(-0.01*np.log(0.99))
  z1011=random.gammavariate(x[1][9][0],1/x[1][9][1])
  z1021=random.gammavariate(x[1][9][0],1/x[1][9][1])
  z1022=random.gammavariate(x[1][9][0],1/x[1][9][1])
  if s>=z1011:
    if s>= z1011+z1021:
      m.append(z1011+z1021+z1022)
    else:
      m.append(z1011+z1021)
  else:
    m.append(z1011)
  s10.append(m[-1])

  #sub11
  s=random.expovariate(-0.01*np.log(0.99))
  z1111=random.gammavariate(x[2][10][0],1/x[2][10][1])
  z1121=random.gammavariate(x[2][10][0],1/x[2][10][1])
  if s>=z1111:
    m.append(z1111+z1121)
  else:
    m.append(z1111)
  s11.append(m[-1])  
  
  #sub12
  s=random.expovariate(-0.01*np.log(0.99))
  z1211=random.gammavariate(x[0][11][0],1/x[0][11][1])
  z1221=random.gammavariate(x[0][11][0],1/x[0][11][1])
  z1222=random.gammavariate(x[0][11][0],1/x[0][11][1])
  z1223=random.gammavariate(x[0][11][0],1/x[0][11][1])
  if s>=z1211:
    if s>= z1211+z1221:
      if s>= z1211+z1221+z1222:
        m.append(z1211+z1221+z1222+z1223)
      else:  
        m.append(z1211+z1221+z1222)
    else:
      m.append(z1211+z1221)
  else:
    m.append(z1211)
  s12.append(m[-1])

  #sub13
  s=random.expovariate(-0.01*np.log(0.99))
  z1311=random.gammavariate(x[1][12][0],1/x[1][12][1])
  z1321=random.gammavariate(x[1][12][0],1/x[1][12][1])
  if s>=z1311:
    m.append(z1311+z1321)
  else:
    m.append(z1311)
  s13.append(m[-1])

  #sub14
  s=random.expovariate(-0.01*np.log(0.99))
  z1411=random.gammavariate(x[2][13][0],1/x[2][13][1])
  z1421=random.gammavariate(x[2][13][0],1/x[2][13][1])
  if s>=z1411:
    m.append(z1411+z1421)
  else:
    m.append(z1411)
  s14.append(m[-1])  

  n.append(min(m))

c=0
for i in n:
  if i>=100:
    c=c+1

c1=0
for i in s1:
  if i>=100:
    c1=c1+1

c2=0
for i in s2:
  if i>=100:
    c2=c2+1

c3=0
for i in s3:
  if i>=100:
    c3=c3+1

c4=0
for i in s4:
  if i>=100:
    c4=c4+1

c5=0
for i in s5:
  if i>=100:
    c5=c5+1

c6=0
for i in s6:
  if i>=100:
    c6=c6+1

c7=0
for i in s7:
  if i>=100:
    c7=c7+1

c8=0
for i in s8:
  if i>=100:
    c8=c8+1

c9=0
for i in s9:
  if i>=100:
    c9=c9+1

c10=0
for i in s10:
  if i>=100:
    c10=c10+1

c11=0
for i in s11:
  if i>=100:
    c11=c11+1

c12=0
for i in s12:
  if i>=100:
    c12=c12+1

c13=0
for i in s13:
  if i>=100:
    c13=c13+1

c14=0
for i in s14:
  if i>=100:
    c14=c14+1

reliability=c/re
xx=(c1*c2*c3*c4*c5*c6*c7*c8*c9*c10*c11*c12*c13*c14)/re**14

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
print("reliability senario 5 with simultion(1):", reliability)
#(1): mohasebi koli
print("reliability senario 5 with simultion(2):", xx)
#(2) zarb zir systemha
print("reliability senario 5 in article: 0.989842")
print("............................")
print("sub1:  0.99940484  ", c1/re)
print("sub2:  0.99943404  ", c2/re)
print("sub3:  0.99947199  ", c3/re)
print("sub4:  0.99895957  ", c4/re)
print("sub5:  0.99953947  ", c5/re)
print("sub6:  0.99982610  ", c6/re)
print("sub7:  0.99860445  ", c7/re)
print("sub8:  0.99934642  ", c8/re)
print("sub9:  0.99938225  ", c9/re)
print("sub10: 0.99936391  ", c10/re)
print("sub11: 0.99926007  ", c11/re)
print("sub12: 0.99895024  ", c12/re)
print("sub13: 0.99992009  ", c13/re)
print("sub14: 0.99917988  ", c14/re)
# Out:
# Duration: 0:01:52.973704
# reliability senario 5 with simultion(1): 0.989709
# reliability senario 5 with simultion(2): 0.9897122694004922
# reliability senario 5 in article: 0.989842
# ............................
# sub1:  0.99940484   0.99938
# sub2:  0.99943404   0.999421
# sub3:  0.99947199   0.999529
# sub4:  0.99895957   0.998948
# sub5:  0.99953947   0.999542
# sub6:  0.99982610   0.999825
# sub7:  0.99860445   0.998575
# sub8:  0.99934642   0.998642
# sub9:  0.99938225   0.999582
# sub10: 0.99936391   0.998925
# sub11: 0.99926007   0.999428
# sub12: 0.99895024   0.998762
# sub13: 0.99992009   0.999919
# sub14: 0.99917988   0.999186
